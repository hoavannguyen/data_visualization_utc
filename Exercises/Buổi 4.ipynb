# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.random.randn(10).cumsum()
s = pd.Series(x, index= np.arange(0,100,10))
print(x)
# Out:
# [-1.62107334 -2.31306426 -2.18682413 -2.29313476 -2.46604904 -3.69956286
#  -3.28938536 -3.2315379  -4.97608783 -6.04211582]

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
s.plot(figsize=(11,5))
# Out:
# <AxesSubplot:>

# %%
x = np.random.randn(10,4).cumsum(0)
print(x.shape)
# Out:
# (10, 4)

# %%
x
# Out:
# array([[ 0.51610237, -1.62913786, -0.62095725,  0.87035118],
#        [ 0.16824911, -1.31526128, -0.41147768,  0.95629816],
#        [ 0.10612399, -2.28773339, -1.52268832,  1.83392077],
#        [ 0.23226376, -1.40725299, -1.57972857,  3.44614082],
#        [ 0.60925221, -1.55200965, -2.7076374 ,  2.46231393],
#        [-0.57569379, -2.06446195, -3.34859241,  2.27722825],
#        [-0.38257259, -1.41330586, -2.36859298,  3.50900402],
#        [-0.25513985, -0.80109012, -1.72783192,  3.54455783],
#        [-0.23067677,  0.26747781, -1.38692845,  2.84879232],
#        [ 0.04681364,  0.8704849 , -0.84909109,  3.87145833]])

# %%
df = pd.DataFrame(x,columns=["A","B","C","D"])

# %%
df
# Out:
#           A         B         C         D
# 0  0.516102 -1.629138 -0.620957  0.870351
# 1  0.168249 -1.315261 -0.411478  0.956298
# 2  0.106124 -2.287733 -1.522688  1.833921
# 3  0.232264 -1.407253 -1.579729  3.446141
# 4  0.609252 -1.552010 -2.707637  2.462314
# 5 -0.575694 -2.064462 -3.348592  2.277228
# 6 -0.382573 -1.413306 -2.368593  3.509004
# 7 -0.255140 -0.801090 -1.727832  3.544558
# 8 -0.230677  0.267478 -1.386928  2.848792
# 9  0.046814  0.870485 -0.849091  3.871458

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Bar plots
fig,axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index= list("abcdefghijklmnop"))
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
data.plot.barh(ax=axes[1],color="k",alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
# a    0.550051
# b    0.947106
# c    0.423912
# d    0.307507
# e    0.960433
# f    0.724953
# g    0.928109
# h    0.734891
# i    0.567181
# j    0.339181
# k    0.384657
# l    0.685412
# m    0.071394
# n    0.625908
# o    0.388369
# p    0.561650
# dtype: float64

# %%
df = pd.DataFrame(np.random.rand(6,4),
                 index=["one","two","three","four","five","six"],
                 columns=pd.Index(["A","B","C","D"],name="Genus"))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.261262  0.247304  0.372247  0.511812
# two    0.847028  0.051181  0.240469  0.587498
# three  0.329416  0.261157  0.268471  0.595766
# four   0.753901  0.769086  0.375517  0.083660
# five   0.887833  0.643081  0.258527  0.366409
# six    0.839625  0.149328  0.874637  0.452947

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha= 0.8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![image.png](attachment:image.png)
